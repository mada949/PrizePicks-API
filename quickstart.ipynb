# %%
import requests

# %%
url = 'http://partner-api.prizepicks.com/leagues'

# %%
requests.get(url).json()
# Out:
# {'data': [{'id': '150',
#    'type': 'league',
#    'attributes': {'name': 'CFB2H',
#     'rank': 0,
#     'active': True,
#     'created_at': '2020-09-23T10:34:52.470-04:00',
#     'updated_at': '2021-08-30T07:21:18.109-04:00',
#     'icon': 'football',
#     'image_url': 'https://static.prizepicks.com/images/leagues/football.svg',
#     'projections_count': 0},
#    'relationships': {'projection_filters': {'data': []}}},
#   {'id': '9',
#    'type': 'league',
#    'attributes': {'name': 'NFL',
#     'rank': 1,
#     'active': True,
#     'created_at': '2018-07-19T13:26:11.622-04:00',
#     'updated_at': '2021-08-30T07:21:18.116-04:00',
#     'icon': 'football',
#     'image_url': 'https://static.prizepicks.com/images/leagues/football.svg',
#     'projections_count': 34},
#    'relationships': {'projection_filters': {'data': [{'id': '1',
#        'type': 'projection_filter'},
#       {'id': '2', 'type': 'projection_filter'},
#       {'id': '15', 'type': 'projection_filter'},
# ...
